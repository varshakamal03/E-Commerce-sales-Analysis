# %%
import pandas as pd
from sqlalchemy import create_engine,MetaData
import mysql.connector

# %%
sqlserver = create_engine(
    'mysql+mysqlconnector://root:root@localhost:3306/ecommerce_sales'
)

# %%
df = pd.read_sql(
    "select * from ecommerce_sales_analysis",sqlserver
)

# %%
df
# Out:
#       order_id           order_date order_status sales_channel  customer_id  \
# 0          854  2025-10-25 20:51:00      Shipped       Website            1
# 1          854  2025-10-25 20:51:00      Shipped       Website            1
# 2          687  2025-10-05 11:29:00   Processing    Mobile App            1
# 3          575  2025-11-05 17:52:00    Cancelled    Mobile App            1
# 4          346  2025-05-12 03:46:00    Delivered    Mobile App            1
# ...        ...                  ...          ...           ...          ...
# 4406      1992  2025-02-06 20:27:00    Delivered       Website          449
# 4407      1992  2025-02-06 20:27:00    Delivered       Website          449
# 4408      1671  2025-11-16 09:22:00    Delivered    Mobile App          449
# 4409      1309  2025-10-03 02:50:00    Delivered       Website          449
# 4410      1197  2025-01-24 02:26:00      Shipped    Mobile App          449
#
# ...

# %%
df.head()
# Out:
#    order_id           order_date order_status sales_channel  customer_id  \
# 0       854  2025-10-25 20:51:00      Shipped       Website            1
# 1       854  2025-10-25 20:51:00      Shipped       Website            1
# 2       687  2025-10-05 11:29:00   Processing    Mobile App            1
# 3       575  2025-11-05 17:52:00    Cancelled    Mobile App            1
# 4       346  2025-05-12 03:46:00    Delivered    Mobile App            1
#
#    customer_name gender  age       city      state  ...    brand quantity  \
# 0  Customer_0001   Male   35  Bengaluru  Karnataka  ...  Brand B        3
# 1  Customer_0001   Male   35  Bengaluru  Karnataka  ...  Brand D        4
# 2  Customer_0001   Male   35  Bengaluru  Karnataka  ...  Brand D        2
# 3  Customer_0001   Male   35  Bengaluru  Karnataka  ...  Brand B        1
# 4  Customer_0001   Male   35  Bengaluru  Karnataka  ...  Brand A        4
#
#   unit_price discount_pct  gross_amount  discount_amount  net_amount  \
# ...

# %%
df.shape
# Out:
# (4411, 23)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4411 entries, 0 to 4410
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         4411 non-null   int64
#  1   order_date       4411 non-null   str
#  2   order_status     4411 non-null   str
#  3   sales_channel    4411 non-null   str
#  4   customer_id      4411 non-null   int64
#  5   customer_name    4411 non-null   str
#  6   gender           4411 non-null   str
#  7   age              4411 non-null   int64
#  8   city             4411 non-null   str
#  9   state            4411 non-null   str
#  10  product_id       4411 non-null   int64
#  11  product_name     4411 non-null   str
#  12  category         4411 non-null   str
#  13  brand            4411 non-null   str
#  14  quantity         4411 non-null   int64
#  15  unit_price       4411 non-null   float64
#  16  discount_pct     4411 non-null   int64
# ...

# %%
df.describe()
# Out:
#           order_id  customer_id          age   product_id     quantity  \
# count  4411.000000  4411.000000  4411.000000  4411.000000  4411.000000
# mean   1238.394695   254.402856    39.720472    50.469961     2.482657
# std     719.862907   143.178647    12.516622    28.828442     1.121974
# min       1.000000     1.000000    18.000000     1.000000     1.000000
# 25%     610.500000   132.000000    28.000000    26.000000     1.000000
# 50%    1230.000000   257.000000    40.000000    50.000000     2.000000
# 75%    1857.000000   380.500000    51.000000    75.000000     3.000000
# max    2500.000000   500.000000    60.000000   100.000000     4.000000
#
#          unit_price  discount_pct   gross_amount  discount_amount  \
# count   4411.000000   4411.000000    4411.000000      4411.000000
# mean   10268.131036      8.154613   25402.967581      2077.889118
# std    13545.521034      7.446385   38774.929567      4733.557245
# ...

# %%
df.isnull().sum()
# Out:
# order_id           0
# order_date         0
# order_status       0
# sales_channel      0
# customer_id        0
# customer_name      0
# gender             0
# age                0
# city               0
# state              0
# product_id         0
# product_name       0
# category           0
# brand              0
# quantity           0
# unit_price         0
# discount_pct       0
# gross_amount       0
# discount_amount    0
# net_amount         0
# payment_method     0
# payment_status     0
# shipping_charge    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# order_id             int64
# order_date             str
# order_status           str
# sales_channel          str
# customer_id          int64
# customer_name          str
# gender                 str
# age                  int64
# city                   str
# state                  str
# product_id           int64
# product_name           str
# category               str
# brand                  str
# quantity             int64
# unit_price         float64
# discount_pct         int64
# gross_amount       float64
# discount_amount    float64
# net_amount         float64
# payment_method         str
# payment_status         str
# shipping_charge    float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['month'] = df['order_date'].dt.month

# %%
df['year'] = df['order_date'].dt.year

# %%
category_sales = df.groupby(
    'category'
)['net_amount'].sum().sort_values(ascending=False)

# %%
category_sales
# Out:
# category
# Electronics       61624431.45
# Home & Kitchen    12056021.70
# Sports            10261586.45
# Fashion            9515547.65
# Beauty             9429333.85
# Name: net_amount, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))

sns.barplot(
    x=category_sales.index,
    y=category_sales.values
)

plt.xticks(rotation=45)
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.show()

# %%
monthly_sales = df.groupby(
    df['order_date'].dt.to_period('M')
)['net_amount'].sum()

monthly_sales.plot(kind='line', figsize=(10,5))

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
df.to_excel('DataCleaning_1.xlsx')
